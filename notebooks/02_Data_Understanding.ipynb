# %% [markdown]
# # Dataset Understanding
#
# ## Objective
#
# The objective of this notebook is to understand the customer churn dataset before performing any preprocessing or analysis.
#
# This notebook focuses on:
#
# - Understanding the dataset structure
# - Identifying feature types
# - Understanding the target variable
# - Detecting missing values
# - Reviewing data quality
# - Creating a data dictionary

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r"D:\Project_ML\customer-churn-prediction\data\raw\Telco_customer_churn.xlsx")

# %%
df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender  ...        Contract  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male  ...  Month-to-month
# 1   34.059281, -118.30742  34.059281 -118.307420  Female  ...  Month-to-month
# 2  34.048013, -118.293953  34.048013 -118.293953  Female  ...  Month-to-month
# 3  34.062125, -118.315709  34.062125 -118.315709  Female  ...  Month-to-month
# 4  34.039224, -118.266293  34.039224 -118.266293    Male  ...  Month-to-month
#
# ...

# %%
df.shape
# Out:
# (7043, 33)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   str
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   str
#  3   State              7043 non-null   str
#  4   City               7043 non-null   str
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   str
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   str
#  10  Senior Citizen     7043 non-null   str
#  11  Partner            7043 non-null   str
#  12  Dependents         7043 non-null   str
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   str
#  15  Multiple Lines     7043 non-null   str
#  16  Internet Service   7043 non-null   str
# ...

# %%
df.describe()
# Out:
#         Count      Zip Code     Latitude    Longitude  Tenure Months  \
# count  7043.0   7043.000000  7043.000000  7043.000000    7043.000000
# mean      1.0  93521.964646    36.282441  -119.798880      32.371149
# std       0.0   1865.794555     2.455723     2.157889      24.559481
# min       1.0  90001.000000    32.555828  -124.301372       0.000000
# 25%       1.0  92102.000000    34.030915  -121.815412       9.000000
# 50%       1.0  93552.000000    36.391777  -119.730885      29.000000
# 75%       1.0  95351.000000    38.224869  -118.043237      55.000000
# max       1.0  96161.000000    41.962127  -114.192901      72.000000
#
#        Monthly Charges  Churn Value  Churn Score         CLTV
# count      7043.000000  7043.000000  7043.000000  7043.000000
# mean         64.761692     0.265370    58.699418  4400.295755
# std          30.090047     0.441561    21.525131  1183.057152
# min          18.250000     0.000000     5.000000  2003.000000
# ...

# %%
df.describe(include="object")
# Out:
# C:\Users\Sejal\AppData\Local\Temp\ipykernel_6056\702825166.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include="object")
#         CustomerID        Country       State         City  \
# count         7043           7043        7043         7043
# unique        7043              1           1         1129
# top     3668-QPYBK  United States  California  Los Angeles
# freq             1           7043        7043          305
#
#                       Lat Long Gender Senior Citizen Partner Dependents  \
# ...

# %%
df.columns
# Out:
# Index(['CustomerID', 'Count', 'Country', 'State', 'City', 'Zip Code',
#        'Lat Long', 'Latitude', 'Longitude', 'Gender', 'Senior Citizen',
#        'Partner', 'Dependents', 'Tenure Months', 'Phone Service',
#        'Multiple Lines', 'Internet Service', 'Online Security',
#        'Online Backup', 'Device Protection', 'Tech Support', 'Streaming TV',
#        'Streaming Movies', 'Contract', 'Paperless Billing', 'Payment Method',
#        'Monthly Charges', 'Total Charges', 'Churn Label', 'Churn Value',
#        'Churn Score', 'CLTV', 'Churn Reason'],
#       dtype='str')

# %%
df.dtypes
# Out:
# CustomerID               str
# Count                  int64
# Country                  str
# State                    str
# City                     str
# Zip Code               int64
# Lat Long                 str
# Latitude             float64
# Longitude            float64
# Gender                   str
# Senior Citizen           str
# Partner                  str
# Dependents               str
# Tenure Months          int64
# Phone Service            str
# Multiple Lines           str
# Internet Service         str
# Online Security          str
# Online Backup            str
# Device Protection        str
# Tech Support             str
# Streaming TV             str
# Streaming Movies         str
# Contract                 str
# Paperless Billing        str
# Payment Method           str
# Monthly Charges      float64
# Total Charges         object
# Churn Label              str
# Churn Value            int64
# Churn Score            int64
# CLTV                   int64
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID              0
# Count                   0
# Country                 0
# State                   0
# City                    0
# Zip Code                0
# Lat Long                0
# Latitude                0
# Longitude               0
# Gender                  0
# Senior Citizen          0
# Partner                 0
# Dependents              0
# Tenure Months           0
# Phone Service           0
# Multiple Lines          0
# Internet Service        0
# Online Security         0
# Online Backup           0
# Device Protection       0
# Tech Support            0
# Streaming TV            0
# Streaming Movies        0
# Contract                0
# Paperless Billing       0
# Payment Method          0
# Monthly Charges         0
# Total Charges           0
# Churn Label             0
# Churn Value             0
# Churn Score             0
# CLTV                    0
# Churn Reason         5174
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Initial Observations
#
# - The dataset contains customer demographic, service usage, billing, and churn information.
# - The target variable is **Churn**.
# - Most features are categorical.
# - Numerical features include **tenure**, **MonthlyCharges**, and **TotalCharges**.
# - `customerID` is a unique identifier and will not be used for model training.
# - Missing values (if any) need to be handled during data cleaning.
# - Duplicate records (if any) need to be verified before removal.

# %% [markdown]
# # Data Dictionary

# %% [markdown]
# | Column Name | Data Type | Description | Category |
# |-------------|-----------|-------------|----------|
# | customerID | Object | Unique identifier for each customer | Identifier |
# | gender | Object | Gender of the customer | Demographic |
# | SeniorCitizen | Integer | Indicates whether customer is a senior citizen | Demographic |
# | Partner | Object | Whether customer has a partner | Demographic |
# | Dependents | Object | Whether customer has dependents | Demographic |
# | tenure | Integer | Number of months the customer has stayed | Customer History |
# | PhoneService | Object | Whether customer has phone service | Service |
# | MultipleLines | Object | Multiple phone lines or not | Service |
# | InternetService | Object | Type of internet service | Service |
# | OnlineSecurity | Object | Online security subscription | Service |
# | OnlineBackup | Object | Online backup subscription | Service |
# | DeviceProtection | Object | Device protection plan | Service |
# | TechSupport | Object | Technical support subscription | Service |
# | StreamingTV | Object | Streaming TV subscription | Entertainment |
# | StreamingMovies | Object | Streaming Movies subscription | Entertainment |
# | Contract | Object | Contract type | Contract |
# | PaperlessBilling | Object | Paperless billing option | Billing |
# | PaymentMethod | Object | Customer payment method | Billing |
# | MonthlyCharges | Float | Monthly amount charged | Financial |
# | TotalCharges | Float | Total amount charged | Financial |
# | Churn | Object | Whether customer left the company | Target |

# %% [markdown]
# # Feature Classification

# %% [markdown]
# ## Identifier
# - customerID
#
# ## Target Variable
# - Churn
#
# ## Numerical Features
# - tenure
# - MonthlyCharges
# - TotalCharges
#
# ## Categorical Features
# - gender
# - Partner
# - Dependents
# - PhoneService
# - MultipleLines
# - InternetService
# - OnlineSecurity
# - OnlineBackup
# - DeviceProtection
# - TechSupport
# - StreamingTV
# - StreamingMovies
# - Contract
# - PaperlessBilling
# - PaymentMethod
